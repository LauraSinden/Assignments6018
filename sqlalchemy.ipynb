# %%
#The library I used was SQLAlchemy. I used the database that I built for BMI 6203  

# SQLAlchemy is a powerful and widely-used open-source SQL toolkit and Object Relational Mapper (ORM) for Python. 
#It provides a flexible and efficient way for Python applications to interact with various types of relational databases.
#SQLAlchemy empowers Python developers to work with relational databases more effectively,
#whether by constructing SQL queries programmatically or by using an object-oriented approach to manage data.

# %%
# !pip install -U ucimlrepo
# !pip install pandas
# !pip install sqlalchemy pandas
from sqlalchemy import create_engine
import pandas as pd

from sqlalchemy import create_engine, inspect
import pandas as pd
# Out:
# Requirement already satisfied: ucimlrepo in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from ucimlrepo) (2.3.3)
# Requirement already satisfied: certifi>=2020.12.5 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from ucimlrepo) (2025.8.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)
# Requirement already satisfied: pandas in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sqlalchemy in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (2.0.44)
# Requirement already satisfied: pandas in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: greenlet>=1 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\laura\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#Find the assays table
from sqlalchemy import create_engine, inspect
import pandas as pd

engine = create_engine(r'sqlite:///C:\Users\Laura\Downloads\ARUPlitelabdatabase.db')


# Create an inspector object
inspector = inspect(engine)

# Get list of all table names in the connected database
table_names = inspector.get_table_names()

print(f"Connected to database file. Found tables: {table_names}")


query = "SELECT * FROM Assays"

# Rerun the read_sql command
df = pd.read_sql(query, engine)
print(df.head())
# Out:
# Connected to database file. Found tables: ['Assays', 'Instruments', 'Orders', 'Patient', 'Physician', 'QC', 'Results', 'Specimen Type', 'Specimens']
#    Order ID  20408 Comprehensive Metabolic Panel  99174 Lipoprotein A  \
# 0     22220                                    0                    1
# 1     22221                                    1                    0
# 2     22222                                    0                    0
# 3     22229                                    1                    0
# 4     22230                                    0                    1
#
#    50029 Apolipoprotein B  20399 Basic Metabolic Panel  80525 Vitamin A  \
# 0                       1                            1                0
# 1                       0                            0                0
# 2                       0                            0                0
# 3                       0                            1                0
# 4                       1                            0                0
#
#    20012 Aldolase  50184 Metanephrines, PF  70130 Testosterone  \
# 0               1                        0                   0
# 1               0                        0                   0
# 2               0                        1                   0
# 3               0                        1                   0
# 4               0                        1                   0
#
#    70145 Thyroid Stimulating Hormone   22245 Magnesium
# 0                                   0                0
# 1                                   1                1
# 2                                   0                0
# 3                                   1                1
# 4                                   0                0

# %%
#Find the patient table
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import inspect

# Use a raw string (r prefix) and the correct file extension/path
correct_db_path = r'sqlite:///C:\Users\Laura\Downloads\ARUPlitelabdatabase.db'

engine = create_engine(correct_db_path)

# Verify connection and list tables
inspector = inspect(engine)
table_names = inspector.get_table_names()

print(f"Connected to database file. Found tables: {table_names}")

# If "Patient" appears in the output list, run your query:
if "Patient" in table_names:
    correct_table_name = "Patient" 
    query = f"SELECT * FROM {correct_table_name};"
    df = pd.read_sql(query, engine)
    print(df.head())
else:
    print(f"The 'Patient' table was not found. Found tables: {table_names}")
# Out:
# Connected to database file. Found tables: ['Assays', 'Instruments', 'Orders', 'Patient', 'Physician', 'QC', 'Results', 'Specimen Type', 'Specimens']
#    Patient_ID    MRN First_Name Last_Name         DOB Gender
# 0       12345  43355       Stan    Looney  01-22-1983      M
# 1       22233  49854     Olivia    Rogers  06-06-1966      F
# 2       25254  41658       Maya    Jacobs  04-25-2002      F
# 3       31245  42244      Janis    Joplin  01-19-1943      F
# 4       32129  41158    Brayten    Allred  11-02-2015      M

# %%
#Find order_Id for each assay
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import inspect

# Use a raw string (r prefix) and the correct file extension/path
correct_db_path = r'sqlite:///C:\Users\Laura\Downloads\ARUPlitelabdatabase.db'

engine = create_engine(correct_db_path)

# Verify connection and list tables
inspector = inspect(engine)
table_names = inspector.get_table_names()

print(f"Connected to database file. Found tables: {table_names}")

# If "Patient" appears in the output list, run your query:
if "Patient" in table_names:
    correct_table_name = "Assays" 
    query = f"SELECT * FROM {correct_table_name};"
    df = pd.read_sql(query, engine)
    print(df.head())
else:
    print(f"The 'Patient' table was not found. Found tables: {table_names}")
# Out:
# Connected to database file. Found tables: ['Assays', 'Instruments', 'Orders', 'Patient', 'Physician', 'QC', 'Results', 'Specimen Type', 'Specimens']
#    Order ID  20408 Comprehensive Metabolic Panel  99174 Lipoprotein A  \
# 0     22220                                    0                    1
# 1     22221                                    1                    0
# 2     22222                                    0                    0
# 3     22229                                    1                    0
# 4     22230                                    0                    1
#
#    50029 Apolipoprotein B  20399 Basic Metabolic Panel  80525 Vitamin A  \
# 0                       1                            1                0
# 1                       0                            0                0
# 2                       0                            0                0
# 3                       0                            1                0
# 4                       1                            0                0
#
#    20012 Aldolase  50184 Metanephrines, PF  70130 Testosterone  \
# 0               1                        0                   0
# 1               0                        0                   0
# 2               0                        1                   0
# 3               0                        1                   0
# 4               0                        1                   0
#
#    70145 Thyroid Stimulating Hormone   22245 Magnesium
# 0                                   0                0
# 1                                   1                1
# 2                                   0                0
# 3                                   1                1
# 4                                   0                0

# %%
#what is the name of the client who ordered the most testosterone tests
from sqlalchemy import create_engine
import pandas as pd
from sqlalchemy import inspect
engine = create_engine(r'sqlite:///C:\Users\Laura\Downloads\ARUPlitelabdatabase.db')

# 1. Define the SQL query

sql_query = """
SELECT 
    P."Client_Account" AS ClientName,
    COUNT(A."70130 Testosterone") AS TestosteroneTestCount
FROM 
    "Physician" AS P
JOIN 
    "Orders" AS O ON P."Physician ID" = O."Physician_ID"
JOIN 
    "Assays" AS A ON O."Order ID" = A."Order ID"
WHERE 
    A."70130 Testosterone" = 1
GROUP BY 
    ClientName
ORDER BY 
    TestosteroneTestCount DESC
LIMIT 1;
"""

# Execute the query
result_df = pd.read_sql(sql_query, engine)

# Print the result
if not result_df.empty:
    client_name = result_df["ClientName"].iloc[0]
    count = result_df["TestosteroneTestCount"].iloc[0]
    print(f"The client who ordered the most testosterone tests is: {client_name}")
    print(f"Total testosterone tests ordered: {count}")
else:
    print("No results found. Please check your data or column values (e.g., ensure the test value is exactly 1).")
# Out:
# The client who ordered the most testosterone tests is: Denver_Health
# Total testosterone tests ordered: 3

# %%
# Assuming 'engine' is already defined and working:
engine = create_engine(r'sqlite:///C:\Users\Laura\Downloads\ARUPlitelabdatabase.db')

# Inspect columns for both tables
assays_columns = pd.read_sql("PRAGMA table_info(Assays);", engine)['name'].tolist()
physicians_columns = pd.read_sql("PRAGMA table_info(Physician);", engine)['name'].tolist() # Assuming table name is 'Physicians'

print(f"Assays columns: {assays_columns}")
print(f"Physicians columns: {physicians_columns}")
# Out:
# Assays columns: ['Order ID', '20408 Comprehensive Metabolic Panel', '99174 Lipoprotein A', '50029 Apolipoprotein B', '20399 Basic Metabolic Panel', '80525 Vitamin A', '20012 Aldolase', '50184 Metanephrines, PF', '70130 Testosterone', '70145 Thyroid Stimulating Hormone ', '22245 Magnesium']
# Physicians columns: ['Physician ID', 'Client_Account']
